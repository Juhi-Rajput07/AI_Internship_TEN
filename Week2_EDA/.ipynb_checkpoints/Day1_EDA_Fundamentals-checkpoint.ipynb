# %% [markdown]
# # WEEK2 - PYTHON FOR DATA SCIENCE

# %% [markdown]
# # Day 1 - EDA  Fundamentals

# %% [markdown]
# ## What is EDA?
# Exploratory Data Analysis (EDA) is an important step in data analysis where we explore, summarize, and visualize data to understand its structure, detect patterns, identify anomalies, test assumptions, and check relationships between variables before applying any machine learning or statistical models.
#
# ## Why EDA?
# Exploratory Data Analysis (EDA) is crucial because raw data is messy, unpredictable, and full of hidden traps that can ruin your analysis or machine learning models. Skipping EDA is like building a house without checking the foundation—it saves time upfront but risks catastrophic failure later.
#
# ## Why do EDA??
# * Model building
# * Analysis and reporting
# * Validate assumptions
# * Handling missing values
# * feature engineering
# * detecting outliers
#
# ## Types of EDA
# EDA is divided into four types based on how many variables you look at and whether you use numbers or charts:
#
# 1. Univariate Non-Graphical
# * What it does: Looks at one variable using numbers.
# * Examples: Calculating the average age, median income, or standard deviation.
#
# 2. Univariate Graphical
# * What it does: Looks at one variable using charts.
# * Examples: Using a Histogram to see data shape or a Box Plot to find outliers.
#
# 3. Multivariate Non-Graphical
# * What it does: Looks at multiple variables using numbers.
# * Examples: A Correlation Matrix showing how strongly two variables relate to each other.
#
# 4. Multivariate Graphical
# * What it does: Looks at multiple variables using charts.
# * Examples: A Scatter Plot to see trends or a Heatmap to spot visual correlations.

# %% [markdown]
# ## Step 0: Imports and Reading Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_column', 200)
plt.style.use('ggplot')

# %%
df = pd.read_csv('coaster_db.csv')

# %% [markdown]
# ## Step 1: Data Understanding
# * Dataframe shape
# * head and tail
# * dtypes
# * describe

# %%
df.shape   # this tells us the shape of data
# Out:
# (1087, 56)

# %%
df.head()   #top 5 columns
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.columns  #all columns in the datset
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes # every col is a series nd thats why, every series have a dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()  #tells us info abt the numeric data nd statustic
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ## Step 2: Data Preparation
# * Dropping irrelevant columns and rows
# * Identifying duplicated columns
# * Renaming Columns
# * Feature Creation

# %%
# Examples of dropping column  /single col
# df.drop(['Opening date'], axis=1)

# %%
df = df[['coaster_name', 
       # 'Length', 'Speed', 
       'Location', 'Status', 
       # 'Opening date', 'Type', 
       'Manufacturer',
       # 'Height restriction', 'Model', 'Height',
       # 'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       # 'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       # 'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       # 'Track layout', 'Fastrack available', 'Soft opening date.1',
       # 'Closing date', 'Opened', 'Replaced by', 'Website',
       # 'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       # 'Single rider line available', 'Restraint Style',
       # 'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
       # 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
       # 'height_value', 'height_unit', 
       'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()
        #this copy() is used to makes sur ethat python knows its a brand new dataframe nd not just a reference

# %%
df.dtypes
#here opening_date_clean is object  , so if want to forcibily change this to date time format
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])
# pd_numeric

# %%
#Rename our columns

# we change in key value pair 
df = df.rename(columns ={'coaster_name':'Coaster_Name',
                        'year_introduced': 'Year_Introduced',
                        'opening_date_clean' : 'Opening_Date',
                         'speed_mph': 'Speed_mph',
                        'height_ft': 'Height_Ft', 
                         'Inversions_clean' : 'Inversions', 
                        'Gforce_clean' : 'Gforce'})

# %%
df.isna().sum()  # to see null values
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# latitude           275
# longitude          275
# Type_Main            0
# Opening_Date       250
# Speed_mph          150
# Height_Ft          916
# Inversions           0
# Gforce             725
# dtype: int64

# %%
# df.duplicated()  

df.loc[df.duplicated()] # no duplicates
#The main difference is that df.duplicated() outputs a hidden mask of true/false values, while df.loc[df.duplicated()] converts that mask into a readable table of actual data rows.
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Manufacturer, Year_Introduced, latitude, longitude, Type_Main, Opening_Date, Speed_mph, Height_Ft, Inversions, Gforce]
# Index: []

# %%
# Check for duplicate coaster name

df.loc[df.duplicated(subset=['Coaster_Name'])].head(5)   
#This specific line of code filters your data to look for duplicate values within one specific column: 'Coaster_Name', and then displays only the first 5 rows of those duplicates.
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  Year_Introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
#
#      latitude  longitude Type_Main Opening_Date  Speed_mph  Height_Ft  \
# ...

# %%
# Checking an example duplicate

df.query('Coaster_Name == "Crystal Beach Cyclone"')
#This line of code uses the .query() method to filter your DataFrame and display every row where the roller coaster name matches exactly "Crystal Beach Cyclone".
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  latitude  longitude Type_Main Opening_Date  Speed_mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     Height_Ft  Inversions  Gforce
# 39        NaN           0     4.0
# 43        NaN           0     4.0

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'Opening_Date', 'Speed_mph',
#        'Height_Ft', 'Inversions', 'Gforce'],
#       dtype='object')

# %%
#finding duplicates on (subset of columns)/ or say (a row)

df = df.loc[~df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date' ])] \
    .reset_index(drop=True).copy()
# Find rows where the coaster name, location, and opening date are identical. Keep only the first occurrence, throw away the copies, reset the row numbers from zero, and save it as my clean dataset.

# %% [markdown]
# ## Step 3: Feature Understanding
# (Univariate analysis)
#
# * Plotting Feature Distributions
#     * Histogram
#     * KDE
#     * Boxplot

# %%
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
ax = df['Year_Introduced'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='Top 10 Years Coasters Introduced',rot = 45)  #rot=45 inside the plot function to tilt the year labels for better readability:
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# We use the backslash \ in Python to split a single, long line of code across
# multiple lines in our notebook without breaking the script.
#
# It is called a line continuation character, and it tells Python: "Do not execute this code yet! The instruction continues on the next line.
#
# Without that \, Python reads code row-by-row. It would read the first line, stop at the end of the row, and try to execute it immediately. Then, it would look at line two (.reset_index(drop=True).copy()), get confused because a line cannot start with a dot out of nowhere, and throw a SyntaxError.

# %%
ax = df['Speed_mph'].plot(kind='hist',
                          bins=20,
                          title='Coaster Speed (mph)')
ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
ax = df['Speed_mph'].plot(kind='kde',
                          title='Coaster Speed (mph)')
ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
df['Type_Main'].value_counts()
# Out:
# Type_Main
# Steel    728
# Wood     191
# Other     71
# Name: count, dtype: int64

# %% [markdown]
# ## Step 4: Feature Relationships
#     * Scatterplot
#     * Heatmap Correlation
#     * Pairplot
#     * Groupby comparisons

# %%
df.plot(kind='scatter',
        x='Speed_mph',
        y='Height_Ft',
        title='Coaster Speed vs. Height')
plt.show()

# %%
ax = sns.scatterplot(x='Speed_mph',
                y='Height_Ft',
                hue='Year_Introduced',
                data=df)
ax.set_title('Coaster Speed vs. Height')
plt.show()

# %%
# Shift + tab to see variables neeeded to provide to this function for it  to work

# %%
# We use a pair plot (or scatterplot matrix) because it is the ultimate shortcut for
# multivariate graphical EDA.

#Instead of writing code for 10 different charts, this single command automatically 
#generates a huge grid of plots comparing every single variable against every
#other variable in your list.

# %%
sns.pairplot(df,
             vars=['Year_Introduced','Speed_mph',
                   'Height_Ft','Inversions','Gforce'],
            hue='Type_Main')
plt.show()

# %%
df_corr = df[['Year_Introduced','Speed_mph',
    'Height_Ft','Inversions','Gforce']].dropna().corr()
df_corr
# Out:
#                  Year_Introduced  Speed_mph  Height_Ft  Inversions    Gforce
# Year_Introduced         1.000000   0.171978   0.135413   -0.209887  0.160247
# Speed_mph               0.171978   1.000000   0.733999   -0.028705  0.607383
# Height_Ft               0.135413   0.733999   1.000000   -0.079736  0.466482
# Inversions             -0.209887  -0.028705  -0.079736    1.000000  0.275991
# Gforce                  0.160247   0.607383   0.466482    0.275991  1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Step 5: Ask a Question about the data
# * Try to answer a question you have about the data using a plot or statistic.
#
# What are the locations with the fastest roller coasters (minimum of 10)?

# %%
ax = df.query('Location != "Other"') \
    .groupby('Location')['Speed_mph'] \
    .agg(['mean','count']) \
    .query('count >= 10') \
    .sort_values('mean')['mean'] \
    .plot(kind='barh', figsize=(12, 5), title='Average Coast Speed by Location')
ax.set_xlabel('Average Coaster Speed')
plt.show()

# %% [markdown]
# # MINI TASK --- Day1
# # (QUESTIONS)

# %%
# data = pd.read_csv('coaster_db.csv')

# %%
# HOW MANY ROWS AND COLUMNS ARE THERE ?

df.shape  #-- of new dataset
# Out:
# (990, 13)

# %%
# WHICH COLUMNS CONTAIN MISSING VALUES?

df.columns[df.isna().any()].tolist()  #----->this is quick fix

# Another method
# missing_counts = data.isna().sum()
# missing_counts[missing_counts > 0]
# Out:
# ['Status',
#  'Manufacturer',
#  'latitude',
#  'longitude',
#  'Opening_Date',
#  'Speed_mph',
#  'Height_Ft',
#  'Gforce']

# %%
# WHICH COASTER HAS THE HIGHEST SPEED?

df.sort_values('Speed_mph', ascending=False).head(1)['Coaster_Name'].values[0]
# Out:
# 'Formula Rossa'

# %%
# WHICH COASTER HAS THE GREATEST HEIGHT?
df.sort_values('Height_Ft',ascending = False).head(1)['Coaster_Name'].values[0]

# Summary AnalogyThink of the dataframe as a bookcase.  ['Coaster_Name'] pulls out the specific binder labeled "Names"..values opens the binder to look at the raw list of pages inside.[0] reads the very first word written at the top of page one.
# Out:
# 'Tower of Terror II'

# %%
# WHICH PARK APPEARS MOST FREQUENTLY ?

df['Location'].value_counts().head(1)

# value_counts() → counts every unique park/location.
# head(1) → shows the top result with its count.
# idxmax() → returns only the name of the most frequent park.
# Out:
# Location
# Other    181
# Name: count, dtype: int64

# %%
# CHOOSE ONE NUMERICAL COLUMN CREATE HISTOGRAM.
# Write 2 observatins.

df['Speed_mph'].plot(kind='hist', title='Coaster Speed Histogram')
# Out:
# <Axes: title={'center': 'Coaster Speed Histogram'}, ylabel='Frequency'>

# %%
# CHOOSE ONE CATEGORICAL COLUMN AND CREATE A COUNT PLOT(OR BAR CHART)
#Write 2 observations.

ax = df['Type_Main'].value_counts().plot(kind = 'bar', title = 'Distribution of Roller Coaster Material Types')
ax.set_xlabel('Material Type')
ax.set_ylabel('Number of Coasters')
# Out:
# Text(0, 0.5, 'Number of Coasters')

# %%
# WHICH MANUFACTURER APPEARS MOST FRQUENTLY?
df['Manufacturer'].value_counts().head(1)
# Out:
# Manufacturer
# Vekoma    122
# Name: count, dtype: int64
